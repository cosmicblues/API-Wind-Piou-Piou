# %%
import requests

# %%
import json

# %%
response = requests.get('http://api.pioupiou.fr/v1/live/all').text

# %%
response_1 = json.loads(response)

# %%
response_1
# Out:
# {'doc': 'http://developers.pioupiou.fr/api/live/',
#  'license': 'http://developers.pioupiou.fr/data-licensing',
#  'attribution': '(c) contributors of the Pioupiou wind network <http://pioupiou.fr>',
#  'data': [{'id': 19,
#    'meta': {'name': 'Pioupiou 19'},
#    'location': {'latitude': 0, 'longitude': 0, 'date': None, 'success': False},
#    'measurements': {'date': '2021-03-10T10:11:21.000Z',
#     'pressure': None,
#     'wind_heading': 67.5,
#     'wind_speed_avg': 2,
#     'wind_speed_max': 2,
#     'wind_speed_min': 1},
#    'status': {'date': '2021-03-10T10:11:21.000Z', 'snr': 0, 'state': 'on'}},
#   {'id': 23,
#    'meta': {'name': 'Lac de Monteynard - Nord'},
#    'location': {'latitude': 44.907438,
#     'longitude': 5.677981,
#     'date': '2021-03-07T13:03:32.000Z',
#     'success': True},
#    'measurements': {'date': '2021-03-10T10:08:34.000Z',
#     'pressure': None,
#     'wind_heading': 22.5,
#     'wind_speed_avg': 11,
#     'wind_speed_max': 15.5,
# ...
